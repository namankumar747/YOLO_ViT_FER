# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="path_to\FER_ViT\dataset\data.yaml",
    epochs=8,
    imgsz=256,
    batch=4
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.22 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.192  Python-3.9.25 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...
